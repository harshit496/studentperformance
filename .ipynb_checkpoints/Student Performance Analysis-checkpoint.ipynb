# %%
import pandas as pd 
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix

# %%
df = pd.read_csv('StudentsPerformance.csv')
df.describe(include = 'all').transpose()
# Out:
#                             count unique           top freq    mean      std  \
# gender                       1000      2        female  518     NaN      NaN
# race/ethnicity               1000      5       group C  319     NaN      NaN
# parental level of education  1000      6  some college  226     NaN      NaN
# lunch                        1000      2      standard  645     NaN      NaN
# test preparation course      1000      2          none  642     NaN      NaN
# math score                   1000    NaN           NaN  NaN  66.089  15.1631
# reading score                1000    NaN           NaN  NaN  69.169  14.6002
# writing score                1000    NaN           NaN  NaN  68.054  15.1957
#
#                              min    25%  50%  75%  max
# gender                       NaN    NaN  NaN  NaN  NaN
# race/ethnicity               NaN    NaN  NaN  NaN  NaN
# parental level of education  NaN    NaN  NaN  NaN  NaN
# ...

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
df.hist(bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1a232e2a10>,
# ...
#       dtype=object)

# %%
def plot_piecharts(row,col,columns,df):
#     row,col = 3,2
    index = 0
    # columns = df.columns[:5]
    f, axes = plt.subplots(nrows=row,ncols=col, figsize=(10,10))

    for i in range(row):
        for j in range(col):
            
            if index < len(columns):
                
                axes[i][j].pie(df[columns[index]].value_counts(), labels=df[columns[index]].unique(), autopct='%1.1f%%',
                shadow=True, startangle=90)
                axes[i][j].set_title(columns[index])
                index+=1
    axes[-1,-1].axis('off')
    plt.tight_layout()
    plt.show()
    
plot_piecharts(3,2,df.columns[:5],df)

# %%
#calculating the total score
if not 'total score' in df.columns:
    df['total score'] = df[['math score', 'reading score',
           'writing score']].sum(axis=1)
df.describe().transpose()
# BP
# [item.get_xdata()for item in BP['whiskers']]
# Out:
#                 count     mean        std   min     25%    50%    75%    max
# math score     1000.0   66.089  15.163080   0.0   57.00   66.0   77.0  100.0
# reading score  1000.0   69.169  14.600192  17.0   59.00   70.0   79.0  100.0
# writing score  1000.0   68.054  15.195657  10.0   57.75   69.0   79.0  100.0
# total score    1000.0  203.312  42.771978  27.0  175.00  205.0  233.0  300.0

# %%
BP = plt.boxplot(df['total score'],vert = False)

# %%
above_median = df[df['total score'] > df['total score'].median()]
plot_piecharts(2,2,['parental level of education', 'test preparation course','gender'],above_median)

# %%
above_mean = df[df['total score'] > df['total score'].mean()]
plot_piecharts(2,2,['parental level of education', 'test preparation course','gender'],above_mean)

# %%
above_q3 = df[df['total score'] > df['total score'].quantile(0.9)]
plot_piecharts(2,2,['parental level of education', 'test preparation course','gender'],above_q3)

# %%
readingreading

# %%
above_median.head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 4    male        group C                some college  standard
# 5  female        group B          associate's degree  standard
#
#   test preparation course  math score  reading score  writing score  \
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 4                    none          76             78             75
# 5                    none          71             83             78
#
#    total score
# 0          218
# 1          247
# 2          278
# 4          229
# 5          232

# %%
df['race/ethnicity'].value_counts().plot.bar()

# %%
for col in df.columns:
    print (df[col].isnull().value_counts())
# Out:
# False    1000
# Name: gender, dtype: int64
# False    1000
# Name: race/ethnicity, dtype: int64
# False    1000
# Name: parental level of education, dtype: int64
# False    1000
# Name: lunch, dtype: int64
# False    1000
# Name: test preparation course, dtype: int64
# False    1000
# Name: math score, dtype: int64
# False    1000
# Name: reading score, dtype: int64
# False    1000
# Name: writing score, dtype: int64

# %%
'''
Prediction possibilities 
1. Which gender performed well
2. 
'''

# %%
#Logistic regression
features = df[['math score', 'reading score','writing score']]
labels = pd.DataFrame(np.where(df['gender'] == 'male', 1, 0),columns=['gender'])

#train-test split
features_train, features_test, labels_train, labels_test = train_test_split(features,labels,test_size = 0.2)

#train model
clf = LogisticRegression(random_state=0).fit(features_train,labels_train )
# Predict model
labels_pred = clf.predict(features_test)

#accuracy
accuracy = clf.score(features_test,labels_test)

print ('The accuracy of the model is ',accuracy*100,'%')
confusion_matrix(labels_test,labels_pred)
# Out:
# The accuracy of the model is  91.5 %
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/utils/validation.py:724: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# array([[90,  6],
#        [11, 93]])
